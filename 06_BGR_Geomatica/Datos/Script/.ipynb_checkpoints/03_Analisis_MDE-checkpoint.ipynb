# %% [markdown]
# # Análsis de MDE

# %%
import os, glob

# %%
# Directorio de trabajo Landsat
os.chdir(r"D:\Descarga")
os.getcwd()
# Out:
# 'D:\\Descarga'

# %%
Lista = glob.glob("*.tif")
Lista
# Out:
# ['MDE_Clas.tif', 'MDE_SRTM.elevation.tif']

# %%
import rasterio

# %%
MDE = rasterio.open(Lista[1])

# %%
MDE.res
# Out:
# (30.0, 30.0)

# %%
MDE_R = MDE.read(1)

# %%
import matplotlib.pyplot as plt

# %%
# Ploteamos el resultado
plt.figure(figsize = (8,5))
plt.imshow(MDE_R, cmap='RdYlGn') # jet, Spectral, Viridis, RdYlGn
plt.colorbar()
plt.title("Mapa de MDE")
plt.xlabel("Numero de Columna") # etiqueta X
plt.ylabel("Numero de Fila") # etiqueta Y
plt.show()

# %%
## Caracteristicas del MDE

# %%
print("Valor minimo MDE:", MDE_R.min())
print("Valor maximo MDE:", MDE_R.max())
print("Valor promedio MDE:", round(MDE_R.mean(),3))
print("Valor desviasion estandar MDE:", round(MDE_R.std(),3))
print("Valor varianza MDE:", round(MDE_R.var(),3))
print("Dimensiones MDE:", MDE_R.shape)
print("Tipo dato MDE:", MDE_R.dtype)
print("Total de pixcel MDE:", MDE_R.size)
# Out:
# Valor minimo MDE: 157
# Valor maximo MDE: 300
# Valor promedio MDE: 198.501
# Valor desviasion estandar MDE: 18.162
# Valor varianza MDE: 329.856
# Dimensiones MDE: (201, 337)
# Tipo dato MDE: int16
# Total de pixcel MDE: 67737

# %%
from osgeo import gdal

# %%
import subprocess

# %%
salida = 'curvas_de_nivel_20m.shp'

# %%
# Intervalo de las curvas de nivel
intervalo = 20  # Intervalo entre las curvas de nivel

# %%
# Ejecutar gdal_contour para generar las curvas de nivel
comando = ['gdal_contour', '-a', 'elevacion', '-i', str(intervalo), Lista[1], salida]
subprocess.call(comando)
# Out:
# 0

# %%
contour_levels = np.arange(0, np.max(MDE_R), 20)

# %%
# Paso 4: Visualizar las curvas de nivel
plt.figure(figsize=(8, 5))
plt.contour(MDE_R, levels=contour_levels, colors='black')
plt.imshow(MDE_R, cmap='terrain', alpha=0.5)
plt.colorbar(label='Elevación (m)')
plt.title('Curvas de Nivel del MDE')
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Clasificación MDE

# %%
import numpy as np

# %%
Clasifi = [-np.Inf, 170, 200, 240, np.Inf]
Clasifi
# Out:
# [-inf, 170, 200, 240, inf]

# %%
MDE_Class = np.digitize(MDE_R, Clasifi)
MDE_Class
# Out:
# array([[2, 2, 2, ..., 1, 1, 2],
#        [2, 2, 3, ..., 1, 1, 1],
#        [3, 3, 3, ..., 1, 1, 1],
#        ...,
#        [3, 3, 2, ..., 2, 3, 3],
#        [3, 3, 3, ..., 3, 3, 3],
#        [3, 3, 3, ..., 2, 3, 3]], dtype=int64)

# %%
# Ploteamos el resultado
plt.figure(figsize = (8,5))
plt.imshow(MDE_Class, cmap='RdYlGn') # jet, Spectral, Viridis, RdYlGn
plt.colorbar()
plt.title("Clasificación MDE")
plt.xlabel("Numero de Columna") # etiqueta X
plt.ylabel("Numero de Fila") # etiqueta Y
plt.show()

# %%
# Guardar tipo de dato int - entero
MDE_Class = MDE_Class.astype(int)
MDE_Class
# Out:
# array([[2, 2, 2, ..., 1, 1, 2],
#        [2, 2, 3, ..., 1, 1, 1],
#        [3, 3, 3, ..., 1, 1, 1],
#        ...,
#        [3, 3, 2, ..., 2, 3, 3],
#        [3, 3, 3, ..., 3, 3, 3],
#        [3, 3, 3, ..., 2, 3, 3]])

# %%
MDE_Class.dtype
# Out:
# dtype('int32')

# %%
param = MDE.meta
param
# Out:
# {'driver': 'GTiff',
#  'dtype': 'int16',
#  'nodata': -32768.0,
#  'width': 337,
#  'height': 201,
#  'count': 1,
#  'crs': CRS.from_epsg(32718),
#  'transform': Affine(30.0, 0.0, 520710.0,
#         0.0, -30.0, 9034020.0)}

# %%
param_clas = MDE.meta
param_clas.update(count = 1,
                  nodata = None,
                  dtype= 'int32')
param_clas
# Out:
# {'driver': 'GTiff',
#  'dtype': 'int32',
#  'nodata': None,
#  'width': 337,
#  'height': 201,
#  'count': 1,
#  'crs': CRS.from_epsg(32718),
#  'transform': Affine(30.0, 0.0, 520710.0,
#         0.0, -30.0, 9034020.0)}

# %%
os.getcwd()
# Out:
# 'D:\\Descarga'

# %%
# Exportamos una banda MDE Clasificado
with rasterio.open("MDE_Clas.tif", 'w', **param_clas) as DATOS:
    DATOS.write_band(1, MDE_Class)
