# %% [markdown]
# # Crear una zona de rectangulo del área interes

# %%
import os, glob
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

# %%
os.chdir(r"C:\Users\GEOMATICA\Curso_Geomatica\06_BGR_Geomatica\Datos\Shp")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\GEOMATICA\\Curso_Geomatica\\06_BGR_Geomatica\\Datos\\Shp'

# %%
## Lista zip
lista_shp = glob.glob("*.shp")
lista_shp
# Out:
# ['HAL_Microcuenca_UTM.shp',
#  'Zona_HAL_Microcuenca_UTM1.shp',
#  'Zona_Parcela.shp']

# %%
shp = os.getcwd() + "\\" + lista_shp[0]
shp
# Out:
# 'C:\\Users\\GEOMATICA\\Curso_Geomatica\\06_BGR_Geomatica\\Datos\\Shp\\HAL_Microcuenca_UTM.shp'

# %%
Vuelo_shp = gpd.read_file(shp)

# %%
Vuelo_shp.head(3)
# Out:
#    Shape_Area      Area_Ha                                           geometry
# 0    0.001097  1336.871235  POLYGON Z ((203840.772 9047965.716 0.000, 2038...

# %%
Vuelo_shp.plot(color='none', edgecolor='blue', linestyle='dashed')
# Out:
# <Axes: >

# %%
envolvente = Vuelo_shp.envelope

# %%
shp_gdp_500 = envolvente.buffer(500, join_style=2)

# %%
# Crear una figura y ejes
fig, ax = plt.subplots()
# Visualizar la shapefile irregular sin color de fondo y con líneas punteadas
Vuelo_shp.plot(ax=ax, color='none', edgecolor='blue', linestyle='dashed')
# Visualizar el envolvente sin color de fondo y con líneas punteadas
shp_gdp_500.plot(ax=ax, color='none', edgecolor='red', linestyle='dashed')
# Configurar título y etiquetas
ax.set_title('área de interés (AOI) y su Zona Buffer y envelope')
ax.set_xlabel('Longitud')
ax.set_ylabel('Latitud')
plt.savefig('Grafico_zona_interes.png')
# Mostrar la visualización
plt.show()

# %%
os.getcwd()
# Out:
# 'C:\\Users\\GEOMATICA\\Curso_Geomatica\\06_BGR_Geomatica\\Datos\\Shp'

# %%
shp_gdp_500.to_file("Zona_buffer_500")

# %% [markdown]
# ## Ubicar el directorio a exportar KML

# %%
import os

# %%
os.chdir('..')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\GEOMATICA\\Curso_Geomatica\\06_BGR_Geomatica\\Datos'

# %%
# Concatenar string o texto 
out_dir = os.path.normpath(os.getcwd() + '/kml' )
out_dir
# Out:
# 'C:\\Users\\GEOMATICA\\Curso_Geomatica\\06_BGR_Geomatica\\Datos\\kml'

# %%
# Crear la carpeta en el directorio
os.makedirs(out_dir)

# %%
# Sino realizar este proceso, si ya cuenta con la carpeta
#out_dir = r"C:\Users\GEOMATICA\Curso_Geomatica\06_BGR_Geomatica\Datos\kml"

# %%
name_kml = out_dir +"\\"+ "Zona_Plan.kml"
name_kml
# Out:
# 'C:\\Users\\GEOMATICA\\Curso_Geomatica\\06_BGR_Geomatica\\Datos\\kml\\Zona_Plan.kml'

# %%
gpd.io.file.fiona.drvsupport.supported_drivers['KML'] = 'rw'
shp_gdp_500.to_file(name_kml, driver="KML")
