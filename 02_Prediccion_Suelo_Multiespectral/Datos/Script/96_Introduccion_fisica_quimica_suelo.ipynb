# %% [markdown]
# # Análisis físico y químico de suelos y recomendaciones de fertilización

# %%
from IPython.display import YouTubeVideo

# %%
display(YouTubeVideo("sHsUVcz5boM", width=500, height=250))
